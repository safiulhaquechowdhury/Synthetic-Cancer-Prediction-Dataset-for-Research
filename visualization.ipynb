# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/synthetic-cancer-prediction-dataset-for-research/cancer_prediction_dataset.csv

# %%
dataset = pd.read_csv('/kaggle/input/synthetic-cancer-prediction-dataset-for-research/cancer_prediction_dataset.csv')

# %%
dataset
# Out:
#       Gender  Age  Smoking  Fatigue  Allergy  Cancer
# 0          1   85        1        0        1       0
# 1          1   93        0        0        0       0
# 2          1   72        0        1        0       0
# 3          0   58        0        0        1       0
# 4          1   95        1        0        1       1
# ...      ...  ...      ...      ...      ...     ...
# 9995       1   89        1        0        1       0
# 9996       0   23        1        1        0       0
# 9997       1   99        0        0        1       0
# 9998       0   26        0        1        1       0
# 9999       1   52        1        1        0       0
#
# [10000 rows x 6 columns]

# %%
X = dataset.drop('Cancer', axis=1)
y = dataset['Cancer']

# %% [markdown]
# # Heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Generate the correlation matrix
correlation_matrix = dataset.corr()

# Set up the matplotlib figure
plt.figure(figsize=(10, 8))

# Generate a heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='Blues', fmt=".2f", linewidths=0.5)

# Set the title and adjust layout
plt.title('Correlation Heatmap OF Cancer Prediction')
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(dataset)
plt.title('Pairplot OF Cancer Prediction')
plt.tight_layout()
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /tmp/ipykernel_20/1388849368.py:3: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %% [markdown]
# # Countplot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size (in inches)
plt.figure(figsize=(25, 6))

# Generate a count plot for the 'Age' column
sns.countplot(data=dataset, x='Age')

# Set the x-axis label
plt.xlabel('Age')

# Set the y-axis label
plt.ylabel('Cancer')

# Set the plot title
plt.title('COUNTPLOT FOR AGE')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size (in inches)
plt.figure(figsize=(5, 4))

# Generate a count plot for the 'Age' column
sns.countplot(data=dataset, x='Gender')

# Set the x-axis label
plt.xlabel('GENDER')

# Set the y-axis label
plt.ylabel('GENDER COUNT')

# Set the plot title
plt.title('COUNTPLOT FOR GENDER')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size (in inches)
plt.figure(figsize=(5, 4))

# Generate a count plot for the 'Age' column
sns.countplot(data=dataset, x='Smoking')

# Set the x-axis label
plt.xlabel('Smoking')

# Set the y-axis label
plt.ylabel('SMOKER COUNT')

# Set the plot title
plt.title('COUNTPLOT FOR SMOKER')

# Show the plot
plt.show()

# %% [markdown]
# # Density Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'dataset' is your DataFrame

# Create subplots
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

# Define the columns for the density plots
columns = ['Gender','Age','Smoking','Fatigue','Allergy','Cancer']
colors = ['blue', 'green', 'red', 'purple', 'orange', 'brown']
# Flatten the axes array for easy iteration
axes = axes.flatten()

# Generate density plots for each column
for i, col in enumerate(columns):
    sns.kdeplot(data=dataset[col], shade=True, ax=axes[i])
    axes[i].set_title(f'Density Plot for {col}')
    axes[i].set_xlabel('Value')
    axes[i].set_ylabel('Density')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()
# Out:
# /tmp/ipykernel_20/2271627328.py:17: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=dataset[col], shade=True, ax=axes[i])
# /tmp/ipykernel_20/2271627328.py:17: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=dataset[col], shade=True, ax=axes[i])
# /tmp/ipykernel_20/2271627328.py:17: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=dataset[col], shade=True, ax=axes[i])
# /tmp/ipykernel_20/2271627328.py:17: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
# ...

# %% [markdown]
# # Histogram

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'dataset' is your DataFrame

# Create subplots
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

# Define the columns for the histograms
columns = ['Gender','Age','Smoking','Fatigue','Allergy','Cancer']
colors = ['blue', 'green', 'red', 'purple', 'orange', 'brown']
# Flatten the axes array for easy iteration
axes = axes.flatten()

# Define colors
colors = ['red', 'blue', 'green', 'purple', 'orange', 'yellow']

# Generate histograms for each column with specified colors
for i, (col, color) in enumerate(zip(columns, colors)):
    sns.histplot(data=dataset[col], color=color, ax=axes[i], kde=True)  # Use sns.histplot for histograms with KDE
    axes[i].set_title(f'Histogram for {col}')
    axes[i].set_xlabel('Value')
    axes[i].set_ylabel('Frequency')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# # Box Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'dataset' is your DataFrame

# Create subplots
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

# Define the columns for the box plots
columns = ['Gender','Age','Smoking','Fatigue','Allergy','Cancer']

# Flatten the axes array for easy iteration
axes = axes.flatten()

# Define colors
colors = ['red', 'blue', 'green', 'purple', 'orange', 'yellow']

# Generate box plots for each column with specified colors
for i, (col, color) in enumerate(zip(columns, colors)):
    sns.boxplot(x=dataset[col], color=color, ax=axes[i])
    axes[i].set_title(f'Box Plot for {col}')
    axes[i].set_xlabel('Value')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()
